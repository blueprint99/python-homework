# %%
from pathlib import Path
import csv
# print(f'File path: {Path.cwd()}')
file_path = Path("budget_data.csv")

# print({file_path.header()})
analysis = {}
delta=[]
month_count = 0
totalrevenue=0
line_num = 0
max_revenue = 0
min_revenue = 0
avg_revenue = 0
# import csv

# print(f"Current Working Directory: {Path.cwd()}")
# months=[]
# profit_loss=0

# Open the csv file as an object
with open(file_path, 'r') as budget_data_raw:
    
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    budget_data = csv.reader(budget_data_raw, delimiter=',')
   
    # Print the header
    csv_header = next(budget_data)
    line_num += 1
    print(csv_header)
#     csv_header.append("Change")   
#     delta.append(csv_header)
    # Read each row of data after the header
    print(csv_header)
   
    previous = int(next(budget_data)[1])
    print(previous)
    for i in range(length(budget_data)):
        row=budget_data[i]
        row2=budget_data[i+1]
#         print(row [1])
        months=row[0]
        profit_loss= int(row[1])

        # Sum the total and count of the numbers in the text file
        totalrevenue += profit_loss
        month_count += 1
        
        #stuck trying to figure out how to use loop to calculate running diff        
#         row.append(totalrevenue)
        
#         print(row)

        changes = profit_loss -previous
        delta.append(changes)
        
        
        
        
        
#         print(changes)
        
#         # Logic to determine min and max 
#         if min_revenue == 0:
#             min_revenue = row
#         elif salary > max_salary:
#         max_salary = salary
#         elif salary < min_salary:
#         min_salary = salary
# print(row)
print(max(delta))
# print(delta)
# max(delta)
print(f'Total Months:{month_count}')
print(f'Total Months:${totalrevenue}')
# Out:
# ['Date', 'Profit/Losses']
# ['Date', 'Profit/Losses']
# 867884
# 302709
# Total Months:85
# Total Months:$37514694
